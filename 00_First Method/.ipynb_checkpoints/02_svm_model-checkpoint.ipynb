# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import seaborn as sns
import matplotlib.pyplot as plt
import joblib

from sklearn import utils
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.linear_model import LogisticRegression
from sklearn import model_selection, naive_bayes, svm
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report


from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
stopwords = stopwords.words('english')

from gensim.models.doc2vec import Doc2Vec, TaggedDocument

# %%
# %run COMBINED.ipynb

# %%
df = pd.read_pickle("00_unwell_well_dataset.pkl")

# %%
df.head()
# Out:
#                                          cleaned_text category
# 5                 f abused different people young age   unwell
# 6   grew dad laying top woke staed continued close...   unwell
# 7             would call mommy ask come wipe bathroom   unwell
# 9              never anything said things stayed away   unwell
# 10  seventh grade became depressed staed self harming   unwell

# %%
def get_behaviors_string(string):
    res = ""
    
    dic = get_behavior_breakdown(string)

    
    for key in dic:
        arr = dic[key]
        for i in arr:
            res += i + " "
        res += key + " "
        
        
    return res

# %%
df["behavioral"] = df["cleaned_text"].apply(lambda x: get_behaviors_string(x))
# Out:
# f abused different people young age
# grew dad laying top woke staed continued close even slept wearing clothes would continues things
# would call mommy ask come wipe bathroom
# never anything said things stayed away
# seventh grade became depressed staed self harming
# eighth grade bullied verbally physically group people though friends
# would threaten hu didnt asked send nudes kiss date
# still scars
# eight grade also first time raped time boyfriend
# guilted sleeping even said continued already happening
# junior year raped different guy friends
# pinned beat didnt fight back anymore
# still scars
# senior year high school manipulated dating guy wanted exclusive
# broke staed stalking house threatening suicide unless got back
# ended call police everything
# made feel guilty eating making much noise kitchen
# stopped eating two weeks one noticed
# left extreme amounts anxiety
# first panic attack th grade
# continue struggle anxiety today
# parents never sent help huing even begged
# growing life easy
# planning making past
# really come terms yet childhood
# try make sense confused get every step take feel like im hit resistance mind
# worried brother
# reason called nspcc dont think eating right think dad emotionally manipulating
# thought riding spilling childhood reason concerned fills dread
# tell others near finally admit area broken
# strong enough itbut keep silent might allow father get away
# selfish coward might condemn brother tried protect fromso ask right help brother ceain anything happening
# supressed summer personal problems occupied mind
# brushed thinking wasnt traumatised beacause built somewhat healthy life never problems sexuality wise denial strongbut came back full force
# cant stop thinking images spin head non stop dont event know feeli talked boyfriend first time told someone
# tears staed flowing shaking since feel really sad empty
# pa still wants think dont trauma memories think thats whats left denial
# lost
# dont know im feeling
# like im huing want heal dont even know hus im stuck constant loop thoughts
# poisoning mind
# dont remember happened specifically really suspect memory repressed tucked away
# memories older sister groomingsabusing period details obviously omitted
# ill say though methodical showing xyz material capture young boys interest manipulating xyz keeping
# generally speaking want touched growing would say bit eating disorder suspect hyper sexual result major trust issues remember mom repeatedly asking throughout childhood someone something used get frustrated saying
# also remember depressed loner kid times
# feeling bit vulnerable
# would also tell intrusive thoughts huing people even
# didnt want go therapy mental health still pretty much taboo country says everyone deals shit im different need accept ithe decided couldnt forget happened thinking would trigger anxiety stress dumped
# twas devastated
# dont know ease anger forgive heal
# trying understand got place changed person dont know get
# fouh grade bullied special ed kids gassy would tell kids faed misunderstood mother told told mother kids calling beans thing rhymes last name mother tell stepdad thought dad would make fun years end
# ended self esteem trust issues
# kid would stand away others reading book cry bathrooms hallways
# dad would make jokes sexuality gender identity acted
# mother told guy raised emotionally hu real father met year old
# cried hard could think doesnt love child
# try hard remember amp get nothing ive therapists years amp theyve tried helping uncover repressed memories ones involving still blank
# recently heard story woman sexually abused child absolutely memory later twenties
# memories events completely suppressed came back slowly marriage husband
# dont know exact details turned sexually abusing two daughters years
# scares childhood always blur especially comes grandmothers
# spent much time practically remember nothing
# anxiety issues therapy year break hiding five years much hated boy scouts parents
# period caused extreme amount stress couldnt bring quit still know
# wasnt issue parents people organization extreme fear confrontation cant explain
# maybe slight aversion men also cant explain
# gets harder everyday
# person help raise teach young age give panic attacks every time im alone home
# every time try help responds telling shut tone voice brings back memories want cry yell everyone everything
# look tone voice triggers im scared turn violance keep punching pillows
# im scared parents wont believe say im making im jealous
# anyway im shaken surprisrd lied serve put best light possible shaken none less
# suddenly im sobbing
# hands tied mistakes im choking
# repoing quite upsetting experience investigation couldnt talk even though needed therapy
# reminded happened changed sexual relationship boyfriend ceain things couldnt anymore without flashback
# means may something used enjoy ends panic attack sensory overload
# molested repeatedly stepdad kid stayed
# ends going shame triggered cant continue
# heabreaking
# didnt want stop sex expressed doubt cured terrified idea leaning darkness left maintaining status quo neither us happy
# conversation end getting emotionally exhausting
# need helpare options available outside four highlighted
# aggressive towards parents allowed point gaslighting isnt huing youre fine escalated sexual abuse
# time high school abuse bad suicidal mother want deal
# would scream asking help
# called names asked see therapist ended running away home age try escape family
# brother would physically harm point screaming
# would get hitbeat mom dad bothering
# learned speak adult life ever
# learned something wrong shut everything results punishment
# trying repair damage done wondering anyone else grew family dynamic like
# therapy male finding hard speak
# right say victim
# unsupervised internet access
# didnt sex hands mouth stuff
# half men talked aim knew young loved liked
# talked fucked things
# knew better
# lied sneaky
# guess good
# wanted even
# fault
# yo sis told story know would feel differently
# feel guilty
# diy
# sad
# angry
# dont right feel bad
# knew
# people much worse
# watching youtube videos nick stars abused triggered bad
# couldnt breathe calm
# still rattled
# im going call work tomorrow havent slept
# feel guilty shouldnt feel way
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-21-c82ca1c44801> in <module>
# ----> 1 df["behavioral"] = df["cleaned_text"].apply(lambda x: get_behaviors_string(x))
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-21-c82ca1c44801> in <lambda>(x)
# ----> 1 df["behavioral"] = df["cleaned_text"].apply(lambda x: get_behaviors_string(x))
#
# <ipython-input-20-9d7cb29ab84a> in get_behaviors_string(string)
#       3     res = ""
#       4
# ----> 5     dic = get_behavior_breakdown(string)
#       6
#       7
#
# <ipython-input-15-6eabd060d6ab> in get_behavior_breakdown(string)
#       1 def get_behavior_breakdown(string):
# ----> 2     li = multi_liaison(string, output="type_dep")
#       3     behaviors = {}
#       4     for group in li:
#       5         if (group[0][1].startswith('JJ') or group[0][1].startswith('VB')) and group[0][0] not in behaviors:
#
# <ipython-input-15-0bd6371df041> in multi_liaison(input_sent, output)
#       7
#       8 def multi_liaison (input_sent, output=['tagging','parse_tree','type_dep','spo','relation']):
# ----> 9     pos_type, parse_tree, dep_type = convert_sentence(input_sent)
#      10     pos_sent = ' '.join([x[0]+'/'+x[1] for x in pos_type])
#      11     # Extract subject, predicate and object
#
# <ipython-input-15-0bd6371df041> in convert_sentence(input_sent)
#       1 def convert_sentence (input_sent):
#       2     # Parse sentence using Stanford CoreNLP Parser
# ----> 3     pos_type = pos_tagger.tag(input_sent.split())
#       4     parse_tree, = ParentedTree.convert(list(pos_tagger.parse(input_sent.split()))[0])
#       5     dep_type, = ParentedTree.convert(dep_parser.parse(input_sent.split()))
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/nltk/parse/corenlp.py in tag(self, sentence)
#     364         ('unladen', 'JJ'), ('swallow', 'VB'), ('?', '.')]
#     365         """
# --> 366         return self.tag_sents([sentence])[0]
#     367
#     368     def raw_tag_sents(self, sentences):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/nltk/parse/corenlp.py in tag_sents(self, sentences)
#     343         # Converting list(list(str)) -> list(str)
#     344         sentences = (" ".join(words) for words in sentences)
# --> 345         return [sentences[0] for sentences in self.raw_tag_sents(sentences)]
#     346
#     347     def tag(self, sentence):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/nltk/parse/corenlp.py in <listcomp>(.0)
#     343         # Converting list(list(str)) -> list(str)
#     344         sentences = (" ".join(words) for words in sentences)
# --> 345         return [sentences[0] for sentences in self.raw_tag_sents(sentences)]
#     346
#     347     def tag(self, sentence):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/nltk/parse/corenlp.py in raw_tag_sents(self, sentences)
#     385         default_properties["annotators"] += self.tagtype
#     386         for sentence in sentences:
# --> 387             tagged_data = self.api_call(sentence, properties=default_properties)
#     388             yield [
#     389                 [
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/nltk/parse/corenlp.py in api_call(self, data, properties, timeout)
#     248         )
#     249
# --> 250         response.raise_for_status()
#     251
#     252         return response.json()
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/models.py in raise_for_status(self)
#     941
#     942         if http_error_msg:
# --> 943             raise HTTPError(http_error_msg, response=self)
#     944
#     945     def close(self):
#
# HTTPError: 500 Server Error: Internal Server Error for url: http://0.0.0.0:9000/?properties=%7B%22outputFormat%22%3A+%22json%22%2C+%22annotators%22%3A+%22tokenize%2Cssplit%2Cpos%22%2C+%22ssplit.isOneSentence%22%3A+%22true%22%7D

# %%
# Out:
# 5                   f abused different people young age
# 6     grew dad laying top woke staed continued close...
# 7               would call mommy ask come wipe bathroom
# 9                never anything said things stayed away
# 10    seventh grade became depressed staed self harming
# 11    eighth grade bullied verbally physically group...
# 12    would threaten hu didnt asked send nudes kiss ...
# 13                                          still scars
# 15     eight grade also first time raped time boyfriend
# 16    guilted sleeping even said continued already h...
# 20              junior year raped different guy friends
# 21                 pinned beat didnt fight back anymore
# 22                                          still scars
# 24    senior year high school manipulated dating guy...
# 29    broke staed stalking house threatening suicide...
# 30                         ended call police everything
# 36    made feel guilty eating making much noise kitchen
# 37                 stopped eating two weeks one noticed
# 39                         left extreme amounts anxiety
# 40                          first panic attack th grade
# 41                      continue struggle anxiety today
# 42            parents never sent help huing even begged
# 46                                    growing life easy
# 50                                 planning making past
# 65                      really come terms yet childhood
# 66    try make sense confused get every step take fe...
# 68                                      worried brother
# 71    reason called nspcc dont think eating right th...
# 78    thought riding spilling childhood reason conce...
# 80           tell others near finally admit area broken
# Name: cleaned_text, dtype: object
